# %%
import pandas as pd
import numpy as np
import  seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("train.csv")
df.shape
# Out:
# (404290, 6)

# %%
df.sample(10)
# Out:
#             id    qid1    qid2  \
# 84859    84859   20010   28722
# 32765    32765   60275   60276
# 245838  245838  358762  358763
# 79799    79799  135793  135794
# 126575  126575  203942  203943
# 127994  127994  205937  205938
# 235461  235461  346176  346177
# 44940    44940   80602   80603
# 332372  332372  459363  459364
# 320198  320198   18925   24778
#
#                                                 question1  \
# 84859           How can I lose weight quickly in 2 weeks?
# 32765                  Can I play ps3 games on my laptop?
# 245838           How do I stop regretting my nationality?
# 79799   Who invented the first touch screen phone? By ...
# 126575                      How many volts will kill you?
# 127994                            What dog breed is this?
# 235461                 What is the most intelligent A.I.?
# 44940              What is Henry David Thoreau known for?
# 332372             Who would win in a fight Marvel vs DC?
# 320198           Can I see my video viewers on Instagram?
#
#                                                 question2  is_duplicate
# 84859               How can you lose weight really quick?             1
# 32765   Can PlayStation 3 games be ran (emulated?) on ...             0
# 245838                          How do I stop regretting?             0
# 79799    When will touch screen phones go out of fashion?             0
# 126575                       How many volts can kill you?             1
# 127994                              What dog breeds hunt?             0
# 235461       What are some of the most intelligent books?             0
# 44940               What is Henry David Thoreau's legacy?             1
# 332372  Who would win an all out war between Marvel an...             1
# 320198  How can I see who viewed my video on Instagram...             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Distribution of duplicate and non-duplicate questions

print(df['is_duplicate'].value_counts())
print((df['is_duplicate'].value_counts()/df['is_duplicate'].count())*100)
df['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64
# <Axes: xlabel='is_duplicate'>

# %%
# Repeated questions

qid = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
print('Number of unique questions',np.unique(qid).shape[0])
x = qid.value_counts()>1
print('Number of questions getting repeated',x[x].shape[0])
# Out:
# Number of unique questions 537933
# Number of questions getting repeated 111780

# %%
plt.hist(qid.value_counts().values,bins=160)
plt.
